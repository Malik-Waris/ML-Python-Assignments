# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.4.3-cp39-cp39-win_amd64.whl (11.9 MB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy) (2.27.1)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.3-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy) (21.3)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp39-cp39-win_amd64.whl (18 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.2-py3-none-any.whl (42 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp39-cp39-win_amd64.whl (96 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.5-cp39-cp39-win_amd64.whl (481 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy) (4.64.0)
# Collecting thinc<8.2.0,>=8.1.0
#   Downloading thinc-8.1.5-cp39-cp39-win_amd64.whl (1.3 MB)
# Requirement already satisfied: setuptools in c:\users\malik waris\anaconda3\lib\site-packages (from spacy) (61.2.0)
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.10
#   Downloading spacy_legacy-3.0.10-py2.py3-none-any.whl (21 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp39-cp39-win_amd64.whl (30 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.2-cp39-cp39-win_amd64.whl (2.1 MB)
# Requirement already satisfied: jinja2 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Collecting typer<0.8.0,>=0.3.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\malik waris\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.4)
# Collecting smart-open<6.0.0,>=5.2.1
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\malik waris\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\malik waris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\malik waris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\malik waris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\malik waris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp39-cp39-win_amd64.whl (7.0 MB)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.3-py3-none-any.whl (32 kB)
# Requirement already satisfied: colorama in c:\users\malik waris\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\malik waris\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\malik waris\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: catalogue, srsly, pydantic, murmurhash, cymem, wasabi, typer, smart-open, preshed, confection, blis, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, spacy
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 5.1.0
#     Uninstalling smart-open-5.1.0:
#       Successfully uninstalled smart-open-5.1.0
# Successfully installed blis-0.7.9 catalogue-2.0.8 confection-0.0.3 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.6.2 preshed-3.0.8 pydantic-1.10.2 smart-open-5.2.1 spacy-3.4.3 spacy-legacy-3.0.10 spacy-loggers-1.0.3 srsly-2.4.5 thinc-8.1.5 typer-0.7.0 wasabi-0.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install monkeylearn
# !pip install yake
# !pip install keybert
# !pip install wordcloud
# !pip install pytextrank
# Out:
# Collecting monkeylearn
#   Downloading monkeylearn-3.6.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: requests>=2.8.1 in c:\users\malik waris\anaconda3\lib\site-packages (from monkeylearn) (2.27.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\malik waris\anaconda3\lib\site-packages (from monkeylearn) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\malik waris\anaconda3\lib\site-packages (from requests>=2.8.1->monkeylearn) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\malik waris\anaconda3\lib\site-packages (from requests>=2.8.1->monkeylearn) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\malik waris\anaconda3\lib\site-packages (from requests>=2.8.1->monkeylearn) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\malik waris\anaconda3\lib\site-packages (from requests>=2.8.1->monkeylearn) (3.3)
# Installing collected packages: monkeylearn
# Successfully installed monkeylearn-3.6.0
# Collecting yake
#   Downloading yake-0.4.8-py2.py3-none-any.whl (60 kB)
# Collecting jellyfish
#   Downloading jellyfish-0.9.0-cp39-cp39-win_amd64.whl (26 kB)
# Requirement already satisfied: tabulate in c:\users\malik waris\anaconda3\lib\site-packages (from yake) (0.8.9)
# Requirement already satisfied: click>=6.0 in c:\users\malik waris\anaconda3\lib\site-packages (from yake) (8.0.4)
# Requirement already satisfied: numpy in c:\users\malik waris\anaconda3\lib\site-packages (from yake) (1.21.5)
# Requirement already satisfied: networkx in c:\users\malik waris\anaconda3\lib\site-packages (from yake) (2.7.1)
# Collecting segtok
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: colorama in c:\users\malik waris\anaconda3\lib\site-packages (from click>=6.0->yake) (0.4.4)
# Requirement already satisfied: regex in c:\users\malik waris\anaconda3\lib\site-packages (from segtok->yake) (2022.3.15)
# Installing collected packages: segtok, jellyfish, yake
# Successfully installed jellyfish-0.9.0 segtok-1.5.11 yake-0.4.8
# Collecting keybert
#   Downloading keybert-0.7.0.tar.gz (21 kB)
# Collecting sentence-transformers>=0.3.8
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
# Requirement already satisfied: scikit-learn>=0.22.2 in c:\users\malik waris\anaconda3\lib\site-packages (from keybert) (1.0.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\malik waris\anaconda3\lib\site-packages (from keybert) (1.21.5)
# Collecting rich>=10.4.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\malik waris\anaconda3\lib\site-packages (from rich>=10.4.0->keybert) (2.11.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\malik waris\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\malik waris\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\malik waris\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->keybert) (1.7.3)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: tqdm in c:\users\malik waris\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (4.64.0)
# Collecting torch>=1.6.0
#   Downloading torch-1.13.0-cp39-cp39-win_amd64.whl (167.2 MB)
# Collecting torchvision
#   Downloading torchvision-0.14.0-cp39-cp39-win_amd64.whl (1.1 MB)
# Requirement already satisfied: nltk in c:\users\malik waris\anaconda3\lib\site-packages (from sentence-transformers>=0.3.8->keybert) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-win_amd64.whl (1.1 MB)
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
# Requirement already satisfied: packaging>=20.9 in c:\users\malik waris\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\malik waris\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.1.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\malik waris\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0)
# Requirement already satisfied: filelock in c:\users\malik waris\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.6.0)
# Requirement already satisfied: requests in c:\users\malik waris\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.27.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\malik waris\anaconda3\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.0.4)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-win_amd64.whl (3.3 MB)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\malik waris\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2022.3.15)
# Requirement already satisfied: colorama in c:\users\malik waris\anaconda3\lib\site-packages (from tqdm->sentence-transformers>=0.3.8->keybert) (0.4.4)
# Requirement already satisfied: click in c:\users\malik waris\anaconda3\lib\site-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\malik waris\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\malik waris\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\malik waris\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\malik waris\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (1.26.9)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\malik waris\anaconda3\lib\site-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (9.0.1)
# Building wheels for collected packages: keybert, sentence-transformers
#   Building wheel for keybert (setup.py): started
#   Building wheel for keybert (setup.py): finished with status 'done'
#   Created wheel for keybert: filename=keybert-0.7.0-py3-none-any.whl size=23799 sha256=3a8678df54bbba692f1defcd578fdb4878730b832a030c81c02e9dddc0b9a018
#   Stored in directory: c:\users\malik waris\appdata\local\pip\cache\wheels\68\aa\41\82025d89b0eb97484c9ac7d527abf596765c41733af79f86b0
#   Building wheel for sentence-transformers (setup.py): started
#   Building wheel for sentence-transformers (setup.py): finished with status 'done'
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125940 sha256=c4200a6616ae162b2c10f3e446546783252474141c01bf359484b23b25fc4034
#   Stored in directory: c:\users\malik waris\appdata\local\pip\cache\wheels\71\67\06\162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built keybert sentence-transformers
# Installing collected packages: torch, tokenizers, huggingface-hub, transformers, torchvision, sentencepiece, commonmark, sentence-transformers, rich, keybert
# Successfully installed commonmark-0.9.1 huggingface-hub-0.10.1 keybert-0.7.0 rich-12.6.0 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 torch-1.13.0 torchvision-0.14.0 transformers-4.24.0
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: pillow in c:\users\malik waris\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: matplotlib in c:\users\malik waris\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\malik waris\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\malik waris\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# Collecting pytextrank
#   Downloading pytextrank-3.2.4-py3-none-any.whl (30 kB)
# Collecting graphviz>=0.13
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
# Requirement already satisfied: scipy>=1.7 in c:\users\malik waris\anaconda3\lib\site-packages (from pytextrank) (1.7.3)
# Collecting icecream>=2.1
#   Downloading icecream-2.1.3-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: pygments>=2.7.4 in c:\users\malik waris\anaconda3\lib\site-packages (from pytextrank) (2.11.2)
# Requirement already satisfied: spacy>=3.0 in c:\users\malik waris\anaconda3\lib\site-packages (from pytextrank) (3.4.3)
# Requirement already satisfied: networkx[default]>=2.6 in c:\users\malik waris\anaconda3\lib\site-packages (from pytextrank) (2.7.1)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\malik waris\anaconda3\lib\site-packages (from icecream>=2.1->pytextrank) (0.4.4)
# Requirement already satisfied: asttokens>=2.0.1 in c:\users\malik waris\anaconda3\lib\site-packages (from icecream>=2.1->pytextrank) (2.0.5)
# Requirement already satisfied: executing>=0.3.1 in c:\users\malik waris\anaconda3\lib\site-packages (from icecream>=2.1->pytextrank) (0.8.3)
# Requirement already satisfied: six in c:\users\malik waris\anaconda3\lib\site-packages (from asttokens>=2.0.1->icecream>=2.1->pytextrank) (1.16.0)
# Requirement already satisfied: pandas>=1.3 in c:\users\malik waris\anaconda3\lib\site-packages (from networkx[default]>=2.6->pytextrank) (1.4.2)
# Requirement already satisfied: numpy>=1.19 in c:\users\malik waris\anaconda3\lib\site-packages (from networkx[default]>=2.6->pytextrank) (1.21.5)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\malik waris\anaconda3\lib\site-packages (from networkx[default]>=2.6->pytextrank) (3.5.1)
# Collecting scipy>=1.7
#   Downloading scipy-1.9.3-cp39-cp39-win_amd64.whl (40.2 MB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\malik waris\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (9.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\malik waris\anaconda3\lib\site-packages (from pandas>=1.3->networkx[default]>=2.6->pytextrank) (2021.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (3.0.8)
# Requirement already satisfied: jinja2 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (8.1.5)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (0.6.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (4.64.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (1.0.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.4.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (1.10.2)
# Requirement already satisfied: setuptools in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (61.2.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (0.7.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (3.0.10)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\malik waris\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\malik waris\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy>=3.0->pytextrank) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\malik waris\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=3.0->pytextrank) (4.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\malik waris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\malik waris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\malik waris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\malik waris\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2.0.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\malik waris\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0->pytextrank) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\malik waris\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0->pytextrank) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\malik waris\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy>=3.0->pytextrank) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\malik waris\anaconda3\lib\site-packages (from jinja2->spacy>=3.0->pytextrank) (2.0.1)
# Installing collected packages: scipy, icecream, graphviz, pytextrank
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# Successfully installed graphviz-0.20.1 icecream-2.1.3 pytextrank-3.2.4 scipy-1.9.3

# %%
# !pip install textrazor

# %%
import spacy
from collections import Counter
from string import punctuation
nlp = spacy.load("en_core_web_sm")
def get_hotwords(text):
    result = []
    pos_tag = ['PROPN', 'ADJ', 'NOUN'] 
    doc = nlp(text.lower()) 
    for token in doc:
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        if(token.pos_ in pos_tag):
            result.append(token.text)
    return result
new_text = """
When it comes to evaluating the performance of keyword extractors, you can use some of the standard metrics in machine learning: accuracy, precision, recall, and F1 score. However, these metrics don’t reflect partial matches. they only consider the perfect match between an extracted segment and the correct prediction for that tag.
Fortunately, there are some other metrics capable of capturing partial matches. An example of this is ROUGE.
"""
output = set(get_hotwords(new_text))
most_common_list = Counter(output).most_common(10)
for item in most_common_list:
  print(item[0])

# %%
pip3 install pytextrank
spacy download en_core_web_sm

# %%
import spacy
import pytextrank
# example text
text = "Compatibility of systems of linear constraints over the set of natural numbers. Criteria of compatibility of a system of linear Diophantine equations, strict inequations, and nonstrict inequations are considered. Upper bounds for components of a minimal set of solutions and algorithms of construction of minimal generating sets of solutions for all types of systems are given. These criteria and the corresponding algorithms for constructing a minimal supporting set of solutions can be used in solving all the considered types systems and systems of mixed types."
# load a spaCy model, depending on language, scale, etc.
nlp = spacy.load("en_core_web_sm")
# add PyTextRank to the spaCy pipeline
nlp.add_pipe("textrank")
doc = nlp(text)
# examine the top-ranked phrases in the document
for phrase in doc._.phrases[:10]:
    print(phrase.text)

# %%
import collections
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib import rcParams
from wordcloud import WordCloud, STOPWORDS
all_headlines = """
When it comes to evaluating the performance of keyword extractors, you can use some of the standard metrics in machine learning: accuracy, precision, recall, and F1 score. However, these metrics don’t reflect partial matches; they only consider the perfect match between an extracted segment and the correct prediction for that tag.
Fortunately, there are some other metrics capable of capturing partial matches. An example of this is ROUGE.
"""
stopwords = STOPWORDS
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=1000).generate(all_headlines)
rcParams['figure.figsize'] = 10, 20
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
filtered_words = [word for word in all_headlines.split() if word not in stopwords]
counted_words = collections.Counter(filtered_words)
words = []
counts = []
for letter, count in counted_words.most_common(10):
    words.append(letter)
    counts.append(count)
colors = cm.rainbow(np.linspace(0, 1, 10))
rcParams['figure.figsize'] = 20, 10
plt.title('Top words in the headlines vs their count')
plt.xlabel('Count')
plt.ylabel('Words')
plt.barh(words, counts, color=colors)
plt.show()

# %%
from keybert import KeyBERT

kw_model = KeyBERT()

import pandas as pd
df = pd.read_excel("C:/Users/Malik Waris/Downloads/Output_BBC.xlsx")

keywords = kw_model.extract_keywords(df.Description)
print(keywords)
# Out:
# [[('cyberattack', 0.3635), ('hereford', 0.3439), ('security', 0.3424), ('safeguarding', 0.3178), ('police', 0.3135)], [('ukraine', 0.4352), ('crimea', 0.4222), ('moscow', 0.4073), ('kherson', 0.4035), ('kupiansk', 0.4022)], [('farming', 0.4758), ('plants', 0.4666), ('growing', 0.4022), ('vertical', 0.3868), ('stacked', 0.3349)], [('kilimanjaro', 0.4608), ('climbed', 0.4292), ('vest', 0.3988), ('weight', 0.3771), ('meningitis', 0.3459)], [('refunds', 0.4641), ('refund', 0.4496), ('refunded', 0.4234), ('furniture', 0.3931), ('retailer', 0.3667)], [('tariffs', 0.4567), ('brexit', 0.4443), ('wto', 0.4392), ('tariff', 0.4391), ('negotiations', 0.4027)], [('protein', 0.5471), ('supplement', 0.5095), ('nutrition', 0.4963), ('supplements', 0.4905), ('nutritional', 0.4553)], [('isabel', 0.4676), ('allende', 0.33), ('solitude', 0.3142), ('author', 0.2979), ('travelled', 0.2929)], [('entrepreneur', 0.4942), ('entrepreneurs', 0.4758), ('entrepreneurship', 0.4504), ('ventures', 0.4055), ('investors', 0.3729)], [('telford', 0.4417), ('pavement', 0.4338), ('roadside', 0.3516), ('mobiles', 0.3206), ('electricity', 0.3182)], [('shetland', 0.5196), ('shetlands', 0.4571), ('orkney', 0.4184), ('cable', 0.3868), ('isles', 0.3618)], [('covid', 0.4472), ('wales', 0.4005), ('coronavirus', 0.3857), ('pandemic', 0.3672), ('prevalence', 0.3608)], [('earth', 0.3937), ('gaia', 0.381), ('grimsby', 0.3777), ('imagery', 0.3265), ('globe', 0.3237)], [('climate', 0.4185), ('co2', 0.4127), ('emissions', 0.3946), ('2022', 0.3702), ('2030', 0.3378)], [('instagram', 0.4173), ('gayle', 0.3907), ('tweeting', 0.3589), ('facebook', 0.3519), ('selfie', 0.3488)], [('seaweed', 0.6705), ('toothpaste', 0.5152), ('toiletries', 0.3332), ('cream', 0.3126), ('food', 0.3113)], [('maritime', 0.5309), ('harbour', 0.447), ('marinetraffic', 0.4262), ('ships', 0.4138), ('containerships', 0.4097)], [('listeria', 0.6438), ('listeriosis', 0.601), ('infections', 0.4138), ('outbreak', 0.4075), ('infection', 0.3981)], [('grandchildren', 0.3883), ('hitler', 0.3791), ('generations', 0.3775), ('nazi', 0.368), ('holocaust', 0.3623)], [('thatcher', 0.5103), ('tory', 0.4315), ('liz', 0.4299), ('truss', 0.3959), ('thatcherite', 0.3834)], [('cop26', 0.3428), ('co2', 0.3136), ('climate', 0.3051), ('agreement', 0.303), ('carbon', 0.2977)], [('burials', 0.4082), ('burial', 0.4017), ('grave', 0.3981), ('buried', 0.3793), ('mariupol', 0.3725)], [('tour', 0.4071), ('touring', 0.3647), ('booking', 0.3592), ('concerts', 0.3585), ('tickets', 0.3456)], [('renewable', 0.4687), ('electricity', 0.3709), ('jersey', 0.3645), ('solar', 0.3524), ('roofs', 0.3432)], [('cryptocurrencies', 0.4087), ('ftx', 0.4022), ('cryptocurrency', 0.3867), ('investors', 0.3712), ('financial', 0.3707)], [('kyiv', 0.4924), ('ukraine', 0.4252), ('kherson', 0.4096), ('ukrainians', 0.36), ('ukrainian', 0.3474)], [('republicans', 0.3733), ('wave', 0.3522), ('republican', 0.3412), ('democrats', 0.3409), ('election', 0.2911)], [('influenza', 0.5185), ('flu', 0.5019), ('pandemic', 0.4409), ('vaccinations', 0.4079), ('coronavirus', 0.3757)], [('cruise', 0.4662), ('sailing', 0.4523), ('sailed', 0.4344), ('oceanos', 0.4256), ('seas', 0.3889)], [('tory', 0.4105), ('hancock', 0.3615), ('haverhill', 0.3374), ('celeb', 0.3301), ('constituency', 0.33)], [('ceo', 0.3767), ('social', 0.3605), ('corporations', 0.3553), ('marketing', 0.3524), ('company', 0.3522)], [('sportswear', 0.5337), ('adidas', 0.435), ('fashions', 0.41), ('casuals', 0.4096), ('fashion', 0.4025)], [('pandemic', 0.4697), ('wellbeing', 0.441), ('giang', 0.4085), ('covid', 0.361), ('health', 0.3338)], [('crown', 0.3948), ('royal', 0.3633), ('prince', 0.3563), ('princess', 0.3356), ('elizabeth', 0.3327)], [('gene', 0.4463), ('malaria', 0.4372), ('malarial', 0.4174), ('genetically', 0.4123), ('genes', 0.408)], [('isle', 0.3868), ('ferries', 0.3012), ('offshore', 0.2857), ('isleofman', 0.2834), ('renewable', 0.2683)], [('brazilian', 0.3989), ('singer', 0.3789), ('vida', 0.3753), ('pau ...

# %%
# Out:
# [[('cyberattack', 0.3635), ('hereford', 0.3439), ('security', 0.3424), ('safeguarding', 0.3178), ('police', 0.3135)], [('ukraine', 0.4352), ('crimea', 0.4222), ('moscow', 0.4073), ('kherson', 0.4035), ('kupiansk', 0.4022)], [('farming', 0.4758), ('plants', 0.4666), ('growing', 0.4022), ('vertical', 0.3868), ('stacked', 0.3349)], [('kilimanjaro', 0.4608), ('climbed', 0.4292), ('vest', 0.3988), ('weight', 0.3771), ('meningitis', 0.3459)], [('refunds', 0.4641), ('refund', 0.4496), ('refunded', 0.4234), ('furniture', 0.3931), ('retailer', 0.3667)], [('tariffs', 0.4567), ('brexit', 0.4443), ('wto', 0.4392), ('tariff', 0.4391), ('negotiations', 0.4027)], [('protein', 0.5471), ('supplement', 0.5095), ('nutrition', 0.4963), ('supplements', 0.4905), ('nutritional', 0.4553)], [('isabel', 0.4676), ('allende', 0.33), ('solitude', 0.3142), ('author', 0.2979), ('travelled', 0.2929)], [('entrepreneur', 0.4942), ('entrepreneurs', 0.4758), ('entrepreneurship', 0.4504), ('ventures', 0.4055), ('investors', 0.3729)], [('telford', 0.4417), ('pavement', 0.4338), ('roadside', 0.3516), ('mobiles', 0.3206), ('electricity', 0.3182)], [('shetland', 0.5196), ('shetlands', 0.4571), ('orkney', 0.4184), ('cable', 0.3868), ('isles', 0.3618)], [('covid', 0.4472), ('wales', 0.4005), ('coronavirus', 0.3857), ('pandemic', 0.3672), ('prevalence', 0.3608)], [('earth', 0.3937), ('gaia', 0.381), ('grimsby', 0.3777), ('imagery', 0.3265), ('globe', 0.3237)], [('climate', 0.4185), ('co2', 0.4127), ('emissions', 0.3946), ('2022', 0.3702), ('2030', 0.3378)], [('instagram', 0.4173), ('gayle', 0.3907), ('tweeting', 0.3589), ('facebook', 0.3519), ('selfie', 0.3488)], [('seaweed', 0.6705), ('toothpaste', 0.5152), ('toiletries', 0.3332), ('cream', 0.3126), ('food', 0.3113)], [('maritime', 0.5309), ('harbour', 0.447), ('marinetraffic', 0.4262), ('ships', 0.4138), ('containerships', 0.4097)], [('listeria', 0.6438), ('listeriosis', 0.601), ('infections', 0.4138), ('outbreak', 0.4075), ('infection', 0.3981)], [('grandchildren', 0.3883), ('hitler', 0.3791), ('generations', 0.3775), ('nazi', 0.368), ('holocaust', 0.3623)], [('thatcher', 0.5103), ('tory', 0.4315), ('liz', 0.4299), ('truss', 0.3959), ('thatcherite', 0.3834)], [('cop26', 0.3428), ('co2', 0.3136), ('climate', 0.3051), ('agreement', 0.303), ('carbon', 0.2977)], [('burials', 0.4082), ('burial', 0.4017), ('grave', 0.3981), ('buried', 0.3793), ('mariupol', 0.3725)], [('tour', 0.4071), ('touring', 0.3647), ('booking', 0.3592), ('concerts', 0.3585), ('tickets', 0.3456)], [('renewable', 0.4687), ('electricity', 0.3709), ('jersey', 0.3645), ('solar', 0.3524), ('roofs', 0.3432)], [('cryptocurrencies', 0.4087), ('ftx', 0.4022), ('cryptocurrency', 0.3867), ('investors', 0.3712), ('financial', 0.3707)], [('kyiv', 0.4924), ('ukraine', 0.4252), ('kherson', 0.4096), ('ukrainians', 0.36), ('ukrainian', 0.3474)], [('republicans', 0.3733), ('wave', 0.3522), ('republican', 0.3412), ('democrats', 0.3409), ('election', 0.2911)], [('influenza', 0.5185), ('flu', 0.5019), ('pandemic', 0.4409), ('vaccinations', 0.4079), ('coronavirus', 0.3757)], [('cruise', 0.4662), ('sailing', 0.4523), ('sailed', 0.4344), ('oceanos', 0.4256), ('seas', 0.3889)], [('tory', 0.4105), ('hancock', 0.3615), ('haverhill', 0.3374), ('celeb', 0.3301), ('constituency', 0.33)], [('ceo', 0.3767), ('social', 0.3605), ('corporations', 0.3553), ('marketing', 0.3524), ('company', 0.3522)], [('sportswear', 0.5337), ('adidas', 0.435), ('fashions', 0.41), ('casuals', 0.4096), ('fashion', 0.4025)], [('pandemic', 0.4697), ('wellbeing', 0.441), ('giang', 0.4085), ('covid', 0.361), ('health', 0.3338)], [('crown', 0.3948), ('royal', 0.3633), ('prince', 0.3563), ('princess', 0.3356), ('elizabeth', 0.3327)], [('gene', 0.4463), ('malaria', 0.4372), ('malarial', 0.4174), ('genetically', 0.4123), ('genes', 0.408)], [('isle', 0.3868), ('ferries', 0.3012), ('offshore', 0.2857), ('isleofman', 0.2834), ('renewable', 0.2683)], [('brazilian', 0.3989), ('singer', 0.3789), ('vida', 0.3753), ('pau ...

# %%
import yake
doc = """
         Supervised learning is the machine learning task of learning a function that
         maps an input to an output based on example input-output pairs. It infers a
         function from labeled training data consisting of a set of training examples.
         In supervised learning, each example is a pair consisting of an input object
         (typically a vector) and a desired output value (also called the supervisory signal). 
         A supervised learning algorithm analyzes the training data and produces an inferred function, 
         which can be used for mapping new examples. An optimal scenario will allow for the 
         algorithm to correctly determine the class labels for unseen instances. This requires 
         the learning algorithm to generalize from the training data to unseen situations in a 
         'reasonable' way (see inductive bias)."""
kw_extractor = yake.KeywordExtractor()
keywords = kw_extractor.extract_keywords(doc)
for kw in keywords:
  print(kw)

# %%
from monkeylearn import MonkeyLearn
ml = MonkeyLearn('your_api_key')
my_text = """
When it comes to evaluating the performance of keyword extractors, you can use some of the standard metrics in machine learning: accuracy, precision, recall, and F1 score. However, these metrics don’t reflect partial matches; they only consider the perfect match between an extracted segment and the correct prediction for that tag.
"""
data = [my_text]
model_id = 'your_model_id'
result = ml.extractors.extract(model_id, data)
dataDict = result.body
for item in dataDict[0]['extractions'][:10]:
  print(item['parsed_value'])

# %%
import textrazor
textrazor.api_key = "your_api_key"
client = textrazor.TextRazor(extractors=["entities", "topics"])
response = client.analyze_url("https://www.textrazor.com/docs/python")
for entity in response.entities():
    print(entity.id, entity.relevance_score, entity.confidence_score)
